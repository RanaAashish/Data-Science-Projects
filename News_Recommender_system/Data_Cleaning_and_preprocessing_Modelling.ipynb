# %%
from google.colab import drive
drive.mount('/content/drive')

import pandas as pd
#pd.set_option('max_colwidth', None)

import matplotlib.pyplot as plt
import seaborn as sns
import math

# BOW
# Below libraries are for feature representation using sklearn
from sklearn.feature_extraction.text import CountVectorizer

# Below libraries are for similarity matrices using sklearn
import numpy as np
from sklearn.metrics import pairwise_distances

# tfidf
from sklearn.feature_extraction.text import TfidfVectorizer

# Below libraries are for similarity matrices using sklearn
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# Mounted at /content/drive

# %%
path ="/content/drive/MyDrive/News_Recommendation_System/articles.csv"
df = pd.read_csv(path,index_col=0)

# %%
df.head()
# Out:
#      tag              datetime  \
# 0  sport  29/06/2022, 09:41:10
# 1  sport  29/06/2022, 09:41:13
# 2  sport  29/06/2022, 09:41:17
# 3  sport  29/06/2022, 09:41:20
# 4  sport  29/06/2022, 09:41:24
#
#                                                title   website  \
# 0  Aussie women cricketers’ wage hike fails to cl...  trtworld
# 1  Tennis world concerned over whereabouts of Chi...  trtworld
# 2  Barty pulls out of WTA Finals to focus on Aust...  trtworld
# 3  Beijing lights the flame, kicking off 2022 Win...  trtworld
# 4  Sport bodies boycott social media platforms ov...  trtworld
#
#                                          article_url  \
# 0  https://www.trtworld.com/sport/aussie-women-cr...
# 1  https://www.trtworld.com/sport/tennis-world-co...
# 2  https://www.trtworld.com/sport/barty-pulls-out...
# 3  https://www.trtworld.com/sport/beijing-lights-...
# 4  https://www.trtworld.com/sport/sport-bodies-bo...
#
#                                              article
# 0  ["Australia's women cricketers will get a pay ...
# 1  ['Amid concerns over the whereabouts of Chines...
# 2  ['World number one Ash Barty will not defend h...
# 3  ['China has lit its Olympic flame in Beijing a...
# 4  ["A British football-instigated boycott of the...

# %%
df.shape
# Out:
# (2388, 6)

# %%
df['total_reading_time'] = ""

# %%
df.head()
# Out:
#      tag              datetime  \
# 0  sport  29/06/2022, 09:41:10
# 1  sport  29/06/2022, 09:41:13
# 2  sport  29/06/2022, 09:41:17
# 3  sport  29/06/2022, 09:41:20
# 4  sport  29/06/2022, 09:41:24
#
#                                                title   website  \
# 0  Aussie women cricketers’ wage hike fails to cl...  trtworld
# 1  Tennis world concerned over whereabouts of Chi...  trtworld
# 2  Barty pulls out of WTA Finals to focus on Aust...  trtworld
# 3  Beijing lights the flame, kicking off 2022 Win...  trtworld
# 4  Sport bodies boycott social media platforms ov...  trtworld
#
#                                          article_url  \
# 0  https://www.trtworld.com/sport/aussie-women-cr...
# 1  https://www.trtworld.com/sport/tennis-world-co...
# 2  https://www.trtworld.com/sport/barty-pulls-out...
# 3  https://www.trtworld.com/sport/beijing-lights-...
# 4  https://www.trtworld.com/sport/sport-bodies-bo...
#
#                                              article total_reading_time
# 0  ["Australia's women cricketers will get a pay ...
# 1  ['Amid concerns over the whereabouts of Chines...
# 2  ['World number one Ash Barty will not defend h...
# 3  ['China has lit its Olympic flame in Beijing a...
# 4  ["A British football-instigated boycott of the...

# %%
# count the number of words and assign a time spent on a particluar article
for i in range(0,2388):
  
  words = df['article'][i].split(" ")
  total_reading_time = math.ceil(len(words)/200)
  df['total_reading_time'][i] = total_reading_time

# %%
df.sample(5)
# Out:
#             tag              datetime  \
# 2357  education  29/06/2022, 13:20:14
# 1918  education  29/06/2022, 12:43:26
# 83      cricket  29/06/2022, 09:49:52
# 910      health  29/06/2022, 11:05:15
# 483     samsung  29/06/2022, 10:25:24
#
#                                                   title   website  \
# 2357  Students and police clash at Wits University i...  trtworld
# 1918            Eight most unusual schools in the world  trtworld
# 83    Australia beat England to win cricket Women's ...  trtworld
# 910   WHO: Covid-19 cases on the rise again globally...  trtworld
# 483   Huawei launches new flagship phones in bid to ...  trtworld
#
#                                             article_url  \
# 2357  https://www.trtworld.com/mea/students-and-poli...
# 1918  https://www.trtworld.com/in-depth/eight-most-u...
# 83    https://www.trtworld.com/sport/australia-beat-...
# 910   https://www.trtworld.com/life/who-covid-19-cas...
# 483   https://www.trtworld.com/business/huawei-launc...
#
#                                                 article total_reading_time
# 2357  ["The University of the Witwatersrand has conf...                  3
# 1918  ["It is hard to forget one's school days. Whil...                  6
# 83    ["Australia, led by a sublime 170 from Alyssa ...                  2
# 910   ['Wednesday, October 27, 2021', 'Covid cases s...                  9
# 483   ['Huawei unveiled new flagship smartphones wit...                  2

# %%
df.dtypes

# %%
#create random distribtuion on the time spent on reading article

# generate random integer values
from random import seed
from random import randint
# seed random number generator
seed(1)

df['user_time'] = ""
# generate some integers
for i in range(0,2388):
  value = randint(0, 10)
  df['user_time'][i] = value

import numpy as np
df['user_reading_time'] = np.where((df['total_reading_time'] < df['user_time']) ,df['total_reading_time'], df['user_time'])

df.tail()
# Out:
#           tag              datetime  \
# 2383  cricket  29/06/2022, 13:21:58
# 2384  cricket  29/06/2022, 13:22:01
# 2385  cricket  29/06/2022, 13:22:04
# 2386  cricket  29/06/2022, 13:22:07
# 2387  cricket  29/06/2022, 13:22:10
#
#                                                   title   website  \
# 2383  Afghanistan beat Ireland to qualify for Cricke...  trtworld
# 2384  Australia admit ball tampering in stunning con...  trtworld
# 2385  Australia jeered by South African crowd after ...  trtworld
# 2386       Jones extends England 'dream job' until 2021  trtworld
# 2387           Australia thrash England in Ashes opener  trtworld
#
#                                             article_url  \
# 2383  https://www.trtworld.com/sport/afghanistan-bea...
# 2384  https://www.trtworld.com/sport/australia-admit...
# 2385  https://www.trtworld.com/sport/australia-jeere...
# 2386  https://www.trtworld.com/sport/jones-extends-e...
# 2387  https://www.trtworld.com/sport/australia-thras...
#
#                                                 article total_reading_time  \
# 2383  ["Afghanistan, after losing their opening thre...                  2
# 2384  ['Cricket Australia said Sunday that Steve Smi...                  4
# 2385  ['A muted chorus of boos greeted Australia whe...                  3
# 2386  ['England coach Eddie Jones said winning the 2...                  3
# 2387  ['David Warner and Cameron Bancroft got the re...                  4
#
#      user_time user_reading_time
# 2383         6                 2
# 2384         3                 3
# 2385         0                 0
# 2386         4                 3
# 2387         3                 3

# %%
df.drop(['user_time'],axis = 1 ,inplace = True)

# %%
df.sample(10)
# Out:
#              tag              datetime  \
# 1313    business  29/06/2022, 11:44:15
# 2026    politics  29/06/2022, 12:53:26
# 1265     samsung  29/06/2022, 11:38:54
# 1597  technology  29/06/2022, 12:11:39
# 1967     samsung  29/06/2022, 12:47:35
# 1159    religion  29/06/2022, 11:28:32
# 2218       crime  29/06/2022, 13:08:53
# 165         cars  29/06/2022, 09:56:11
# 1855      google  29/06/2022, 12:35:48
# 335         cars  29/06/2022, 10:12:55
#
#                                                   title   website  \
# 1313  US trade body backs Canada's Bombardier over B...  trtworld
# 2026  At least 39 injured in knife attack at China k...  trtworld
# 1265  Samsung recovers 60 percent of Note 7s from S....  trtworld
# 1597  Nokia phones to expand to high-end while also ...  trtworld
# 1967  Samsung halts Note 7 shipments after battery e...  trtworld
# 1159  Turkey aiming to become top destination for ha...  trtworld
# 2218         Australian police shoot hostage taker dead  trtworld
# 165   EU urged to set phase-out date for new petrol,...  trtworld
# 1855  Huawei founder says US 'underestimates' his co...  trtworld
# 335     Renault drives on to record sales in first half  trtworld
#
#                                             article_url  \
# 1313  https://www.trtworld.com/business/us-trade-bod...
# 2026  https://www.trtworld.com/asia/at-least-39-inju...
# 1265  https://www.trtworld.com/life/samsung-recovers...
# 1597  https://www.trtworld.com/business/nokia-phones...
# 1967  https://www.trtworld.com/business/samsung-halt...
# 1159  https://www.trtworld.com/turkey/turkey-aiming-...
# 2218  https://www.trtworld.com/asia/australian-polic...
# 165   https://www.trtworld.com/business/eu-urged-to-...
# 1855  https://www.trtworld.com/business/huawei-found...
# 335   https://www.trtworld.com/business/renault-driv...
#
#                                                 article total_reading_time  \
# 1313  ["Canada's Bombardier Inc on Friday won an une...                  2
# 2026  ['A school security guard injured at least 39 ...                  2
# 1265  ['More than 60 percent of Galaxy Note 7 smartp...                  1
# 1597  ['Seeking to capitalise on a remarkable comeba...                  1
# 1967  ["Samsung's smartphone fans would be disappoin...                  4
# 1159  ["After reaching a 10-year low in 2016, in the...                  5
# 2218  ['Australian police on Monday shot dead a gunm...                  2
# 165   ['The European Commission should set a date to...                  2
# 1855  ["The US government's temporary easing of trad...                  6
# 335   ['French automaker Renault said on Monday it s...                  2
#
#      user_reading_time
# 1313                 1
# 2026                 2
# 1265                 1
# 1597                 1
# 1967                 2
# 1159                 3
# 2218                 2
# 165                  2
# 1855                 1
# 335                  2

# %% [markdown]
# ###**Inshorts Dataset**

# %%
path ="/content/drive/MyDrive/News_Recommendation_System/news_articles.csv"
df = pd.read_csv(path,index_col=0)

# %%
print(df.dtypes)

# %%
print(f"shape of data =  {df.shape}")
# Out:
# shape of data =  (4453, 3)

# %%
df.columns
# Out:
# Index(['Title', 'Content', 'Category'], dtype='object')

# %%
# distribution of the corpus
plt.figure(figsize = (15,10))
sns.countplot(y = df['Category']);

# %%
# check the null values 
df.isnull().sum()
# Out:
# Title       0
# Content     0
# Category    0
# dtype: int64

# %%
print(f" Duplicated values : {df.duplicated().sum()}")
# Out:
#  Duplicated values : 4079

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df.shape
# Out:
# (374, 3)

# %%
# distribution of the corpus
plt.figure(figsize = (15,10))
sns.countplot(y = df['Category']);

# %% [markdown]
# ###**TRTWorld Dataset**

# %%
path ="/content/drive/MyDrive/News_Recommendation_System/articles.csv"
df = pd.read_csv(path,index_col=0)

# %%
print(df.dtypes)
print(df.shape)
# Out:
# tag            object
# datetime       object
# title          object
# website        object
# article_url    object
# article        object
# dtype: object
# (2388, 6)

# %%
df.head()
# Out:
#      tag              datetime  \
# 0  sport  29/06/2022, 09:41:10
# 1  sport  29/06/2022, 09:41:13
# 2  sport  29/06/2022, 09:41:17
# 3  sport  29/06/2022, 09:41:20
# 4  sport  29/06/2022, 09:41:24
#
#                                                title   website  \
# 0  Aussie women cricketers’ wage hike fails to cl...  trtworld
# 1  Tennis world concerned over whereabouts of Chi...  trtworld
# 2  Barty pulls out of WTA Finals to focus on Aust...  trtworld
# 3  Beijing lights the flame, kicking off 2022 Win...  trtworld
# 4  Sport bodies boycott social media platforms ov...  trtworld
#
#                                          article_url  \
# 0  https://www.trtworld.com/sport/aussie-women-cr...
# 1  https://www.trtworld.com/sport/tennis-world-co...
# 2  https://www.trtworld.com/sport/barty-pulls-out...
# 3  https://www.trtworld.com/sport/beijing-lights-...
# 4  https://www.trtworld.com/sport/sport-bodies-bo...
#
#                                              article
# 0  ["Australia's women cricketers will get a pay ...
# 1  ['Amid concerns over the whereabouts of Chines...
# 2  ['World number one Ash Barty will not defend h...
# 3  ['China has lit its Olympic flame in Beijing a...
# 4  ["A British football-instigated boycott of the...

# %%
# distribution of the corpus
plt.figure(figsize = (15,10))
sns.countplot(y = df['tag']);

# %% [markdown]
# ###**Data Cleaning and Preprocessing**

# %%
# check the null values 
df.isnull().sum()
# Out:
# tag            0
# datetime       0
# title          0
# website        0
# article_url    0
# article        0
# dtype: int64

# %%
print(f" Duplicated values : {df.duplicated().sum()}")
# Out:
#  Duplicated values : 0

# %%
df.head()
# Out:
#      tag              datetime  \
# 0  sport  29/06/2022, 09:41:10
# 1  sport  29/06/2022, 09:41:13
# 2  sport  29/06/2022, 09:41:17
# 3  sport  29/06/2022, 09:41:20
# 4  sport  29/06/2022, 09:41:24
#
#                                                title   website  \
# 0  Aussie women cricketers’ wage hike fails to cl...  trtworld
# 1  Tennis world concerned over whereabouts of Chi...  trtworld
# 2  Barty pulls out of WTA Finals to focus on Aust...  trtworld
# 3  Beijing lights the flame, kicking off 2022 Win...  trtworld
# 4  Sport bodies boycott social media platforms ov...  trtworld
#
#                                          article_url  \
# 0  https://www.trtworld.com/sport/aussie-women-cr...
# 1  https://www.trtworld.com/sport/tennis-world-co...
# 2  https://www.trtworld.com/sport/barty-pulls-out...
# 3  https://www.trtworld.com/sport/beijing-lights-...
# 4  https://www.trtworld.com/sport/sport-bodies-bo...
#
#                                              article
# 0  ["Australia's women cricketers will get a pay ...
# 1  ['Amid concerns over the whereabouts of Chines...
# 2  ['World number one Ash Barty will not defend h...
# 3  ['China has lit its Olympic flame in Beijing a...
# 4  ["A British football-instigated boycott of the...

# %%
#splitting the datetime column
datetime_ = df['datetime'].str.split(",",n=2,expand = True)

# adding the column into original df 
df['date'] = datetime_[0]
df['time'] = datetime_[1]

x = df['date'].str.split("/",n=3,expand = True)
df['day'] = x[0]
df['month'] = x[1]
df['year'] = x[2]

# %%
#splitting the article url column and collecting the keyowrds only 

keywords_from_url = df['article_url'].str.split("/",n=3,expand = True)

# adding the column into original df 

df['keywords_from_url'] = keywords_from_url[3]

# %%
# dropping the columns 

df.drop(['article_url','website','datetime','date'], axis = 1,inplace = True)

# %%
df.head()
# Out:
#      tag                                              title  \
# 0  sport  Aussie women cricketers’ wage hike fails to cl...
# 1  sport  Tennis world concerned over whereabouts of Chi...
# 2  sport  Barty pulls out of WTA Finals to focus on Aust...
# 3  sport  Beijing lights the flame, kicking off 2022 Win...
# 4  sport  Sport bodies boycott social media platforms ov...
#
#                                              article       time day month  \
# 0  ["Australia's women cricketers will get a pay ...   09:41:10  29    06
# 1  ['Amid concerns over the whereabouts of Chines...   09:41:13  29    06
# 2  ['World number one Ash Barty will not defend h...   09:41:17  29    06
# 3  ['China has lit its Olympic flame in Beijing a...   09:41:20  29    06
# 4  ["A British football-instigated boycott of the...   09:41:24  29    06
#
#    year                                  keywords_from_url
# 0  2022  sport/aussie-women-cricketers-wage-hike-fails-...
# 1  2022  sport/tennis-world-concerned-over-whereabouts-...
# 2  2022  sport/barty-pulls-out-of-wta-finals-to-focus-o...
# 3  2022  sport/beijing-lights-the-flame-kicking-off-202...
# 4  2022  sport/sport-bodies-boycott-social-media-platfo...

# %%
# removing html

# this function is not working because we don't have html tags as we already removed it while scraping  

# from bs4 import BeautifulSoup

'''def remove_html(text):
  soup = BeautifulSoup(text,'lxml')
  html_free = soup.get_text()
  return html_free

remove_html(df['article'][0])'''

# %%
# remove the punctuations

# import string for list of punctuations
import string

def remove_punc(text):
  no_punc = "".join([c for c in text if c not in string.punctuation])
  return no_punc

df['title'] = df['title'].apply(lambda x :remove_punc(x))
df['article'] = df['article'].apply(lambda x :remove_punc(x))

# %%
# removing hyphen and slashes from keywords_from_url column

for i in range(0,2388):
  k = df['keywords_from_url'][i]
  df['keywords_from_url'][i] = k.replace("/", " ")

for i in range(0,2388):
  k = df['keywords_from_url'][i]
  df['keywords_from_url'][i] = k.replace("-", " ")

# %%
df.tail()
# Out:
#           tag                                              title  \
# 2383  cricket  Afghanistan beat Ireland to qualify for Cricke...
# 2384  cricket  Australia admit ball tampering in stunning con...
# 2385  cricket  Australia jeered by South African crowd after ...
# 2386  cricket         Jones extends England dream job until 2021
# 2387  cricket           Australia thrash England in Ashes opener
#
#                                                 article       time day month  \
# 2383  Afghanistan after losing their opening three q...   13:21:58  29    06
# 2384  Cricket Australia said Sunday that Steve Smith...   13:22:01  29    06
# 2385  A muted chorus of boos greeted Australia when ...   13:22:04  29    06
# 2386  England coach Eddie Jones said winning the 201...   13:22:07  29    06
# 2387  David Warner and Cameron Bancroft got the requ...   13:22:10  29    06
#
#       year                                  keywords_from_url
# 2383  2022  sport afghanistan beat ireland to qualify for ...
# 2384  2022  sport australia admit ball tampering in stunni...
# 2385  2022  sport australia jeered by south african crowd ...
# 2386  2022  sport jones extends england dream job until 20...
# 2387  2022  sport australia thrash england in ashes opener...

# %%
# there are empty strings in our article columns 
df['article'][1655]

# %%
# filling those empty string with nan value 

nan_value = float("NaN") #Convert NaN values to empty string.
df. replace(" ", nan_value, inplace=True)

# %%
# checking the null values again 

df.isnull().sum()
# Out:
# tag                  0
# title                0
# article              2
# time                 0
# day                  0
# month                0
# year                 0
# keywords_from_url    0
# dtype: int64

# %%
# removing the rows with nan values 

df.dropna(subset=['article'],inplace = True)

# %%
df.shape  # we have droppd two rows
# Out:
# (2386, 8)

# %%
df.sample(5)
# Out:
#              tag  \
# 2271  microsoft
# 157   movies
# 1042  politics
# 2141  technology
# 842   google
#
#                                                                             title  \
# 2271  Web giants to cooperate on eliminating terror content online
# 157   Netflixs latest hiring hints video games could come to streaming platform
# 1042  AOC among liberals and minorities gaining in US congressional primary races
# 2141  US bans Samsung Galaxy Note 7 smartphones from planes
# 842   World Wide Web inventor opposes Australias news payment plan
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 article  \
# 2271  Facebook Twitter Microsoft and Googleowned YouTube announced a drive to stop the proliferation of videos and messages showing beheadings executions and other gruesome content posted by the likes of Daesh or Al Qaeda The new programme announced Monday would create a shared database of unique digital fingerprints to help automatically identify videos or images the companies could remove We hope this collaboration will lead to greater efficiency as we continue to enforce our policies to help curb the pressing global issue of terrorist content online the companies said in a statement  The move comes as social media giants face increasing scrutiny over their role in the explosion of socalled fake news — which is believed to have influenced the US election — as well as online bullying and hate speech Dr Thomas P Keenan talks to TRT World on the issue
# 157   Netflix has hired veteran video game executive Mike Verdu signalling the video streaming service is poised to expand into another fertile field of entertainment Verdus addition as Netflixs vice president of game development confirmed on Thursday comes as the company seeks to sustain the momentum it gathered last year when people turned to the video streaming service to get through lockdowns imposed during the pandemic Netflix wound up adding 37 million worldwide subscribers last year by far the largest annual gain in its history But the landscape has changed dramatically now that the easing pandemic has allowed people to return to a semblance of their normal lives READ MORExa0Netflixs Mank tops Globes nominations as female directors break through Netflix snags former EA Oculus exec to lead its video game efforts httpstcoZA3nHW4UHp pictwittercommWbUVqjAcx The video service stumbled out of the gate during the first three months of this year posting its smallest firstquarter subscriber increase in four years and it predicted its springtime gains would also be meagerxa0 The Los Gatos California company is scheduled to report its results for the AprilJune period on Tuesday Adding video games would give Netflix another way to build upon the nearly 208 million subscribers that it boasted at the end of Marchxa0 It wouldnt come as a surprise either given that Netflix coCEO Reed Hastings has long said the company competes as much against video games for a piece of peoples leisure time as it does against other video streaming services offered by the likes of Amazon Hulu Walt Disney Co and Apple Netflix didnt directly comment on its potential entry into video gaming but left little doubt about its
#
#            time day month  year  \
# 2271   13:12:36  29  06    2022
# 157    09:55:37  29  06    2022
# 1042   11:17:32  29  06    2022
# 2141   13:03:03  29  06    2022
# 842    10:57:29  29  06    2022
#
#                                                                                  keywords_from_url
# 2271  life web giants to cooperate on eliminating terror content online 3970
# 157   art culture netflix s latest hiring hints video games could come to streaming platform 48421
# 1042  americas aoc among liberals and minorities gaining in us congressional primary races 37566
# 2141  americas us bans samsung galaxy note 7 smartphones from planes  3321
# 842   life world wide web inventor opposes australia s news payment plan 43412

# %%
# distribution according to month wise 
# we have all the articles of one date
sns.countplot(x = df['month'])

# %%
# dropping few more columns
df.drop(['time','day','month','year'],axis = 1,inplace = True)

# %%
# length of headline

import plotly.figure_factory as ff
fig = ff.create_distplot([df['title'].str.len()], ["ht"],show_hist=False,show_rug=False)
fig['layout'].update(title={'text':'PDF','y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'}, xaxis_title="Length of a title",yaxis_title="probability")
fig.update_layout(showlegend = False,width=500,height=500)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="fc6277a2-72aa-4820-b0be-bbb77990f2b8" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc6277a2-72aa-4820-b0be-bbb77990f2b8")) {                    Plotly.newPlot(                        "fc6277a2-72aa-4820-b0be-bbb77990f2b8",                        [{"legendgroup":"ht","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"ht","showlegend":true,"x":[20.0,20.11,20.22,20.33,20.44,20.55,20.66,20.77,20.88,20.99,21.1,21.21,21.32,21.43,21.54,21.65,21.76,21.87,21.98,22.09,22.2,22.31,22.42,22.53,22.64,22.75,22.86,22.97,23.08,23.19,23.3,23.41,23.52,23.63,23.740000000000002,23.85,23.96,24.07,24.18,24.29,24.4,24.509999999999998,24.62,24.73,24.84,24.95,25.06,25.17,25.28,25.39,25.5,25.61,25.72,25.83,25.94,26.05,26.16,26.27,26.38,26.490000000000002,26.6,26.71,26.82,26.93,27.04,27.15,27.259999999999998,27.37,27.48,27.59,27.7,27.81,27.92,28.03,28.14,28.25,28.36,28.47,28.58,28.689999999999998,28.8,28.91,29.02,29.130000000000003,29.240000000000002,29.35,29.46,29.57,29.68,29.79,29.9,30.009999999999998,30.119999999999997,30.23,30.34,30.45,30.560000000000002,30.67,30.78,30.89,31.0,31.11,31.22,31.33,31.439999999999998,31.55,31.66,31.77,31.880000000000003,31.990000000000002,32.1,32.21,32.32,32.43,32.54,32.65,32.76,32.87,32.980000000000004,33.09,33.2,33.31,33.42,33.53,33.64,33.75,33.86,33.97,34.08,34.19,34.3,34.41,34.519999999999996,34.63,34.74,34.85,34.96,35.07,35.18,35.29,35.4,35.51,35.62,35.730000000000004,35.84,35.95,36.06,36.17,36.28,36.39,36.5,36.61,36.72,36.83,36.94,37.05,37.16,37.269999999999996,37.379999999999995,37.489999999999995,37.6,37.71,37.82,37.93,38.04,38.15,38.260000000000005,38.370000000000005,38.480000000000004,38.59,38.7,38.81,38.92,39.03,39.14,39.25
# 713   politics  [malaysias, pm, faces, calls, to, quit, after,...
# 1599  business  [farm, workers, shortage, leaves, us, crops, t...
# 768      crime  [new, charges, in, floyd, killing, may, give, ...
#
#                                                 article        date  \
# 1112  [japan, has, joined, leading, figures, in, ten...  29/06/2022
# 1630  [who, are, the, people, behind, these, twitter...  29/06/2022
# 713   [malaysian, prime, ministernmuhyiddin, yassin,...  29/06/2022
# 1599  [mexican, migrants, were, used, to, be, very, ...  29/06/2022
# 768   [prosecutors, seeking, to, put, a, formernminn...  29/06/2022
#
#            time                                  keywords_from_url
# 1112   11:23:47  [sport, support, pours, in, for, naomi, osaka,...
# 1630   12:14:52  [americas, why, are, us, scientists, going, ro...
# 713    10:46:49  [asia, malaysia, s, pm, faces, calls, to, quit...
# 1599   12:12:02  [americas, farm, workers, shortage, leaves, us...
# 768    10:51:42  [americas, new, charges, in, floyd, killing, m...

# %%
# remove stop words after tokenization

nltk.download('stopwords')
# to check the list of the words 
stopwords.words('english')

def remove_stopwords(text):
  words = [w for w in text if w not in stopwords.words('english')]
  return words

df['title'] = df['title'].apply(lambda x : remove_stopwords(x))
df['article'] = df['article'].apply(lambda x : remove_stopwords(x))
df['keywords_from_url'] = df['keywords_from_url'].apply(lambda x : remove_stopwords(x))

# %%
df.sample(5)
# Out:
#              tag                                              title  \
# 1718  technology  Samsung Electronics CEO announces shock resign...
#
#                                                 article       time day month  \
# 1718  Samsung Electronics Co Ltd said on Friday its ...   12:24:06  29    06
#
#       year                                  keywords_from_url headline
# 1718  2022  business samsung electronics ceo announces sho...      NaN

# %%
df.drop(['headline'], axis = 1,inplace = True)

# %%
df.reset_index(drop=True, inplace=True)

# %%
# remove stop words before tokenization

nltk.download('stopwords')
# to check the list of the words 
stopwords.words('english')

stop_words = set(stopwords.words('english'))

for i in range(len(df["title"])):
  print(i)
  string = ""
  for word in df["title"][i].split():
      word = ("".join(e for e in word if e.isalnum()))
      word = word.lower()
      if not word in stop_words:
        string += word + " "  
  if(i%1000==0):
    print(i)           # To track number of records processed
  df.at[i,"title"] = string.strip()

# %%
df.head()
# Out:
#      tag                                              title  \
# 0  sport  aussie women cricketers wage hike fails close ...
# 1  sport  tennis world concerned whereabouts chinas peng...
# 2  sport  barty pulls wta finals focus australian open p...
# 3  sport  beijing lights flame kicking 2022 winter olymp...
# 4  sport  sport bodies boycott social media platforms on...
#
#                                              article  \
# 0  Australias women cricketers will get a pay ris...
# 1  Amid concerns over the whereabouts of Chinese ...
# 2  World number one Ash Barty will not defend her...
# 3  China has lit its Olympic flame in Beijing aft...
# 4  A British footballinstigated boycott of the wo...
#
#                                    keywords_from_url
# 0  sport aussie women cricketers wage hike fails ...
# 1  sport tennis world concerned over whereabouts ...
# 2  sport barty pulls out of wta finals to focus o...
# 3  sport beijing lights the flame kicking off 202...
# 4  sport sport bodies boycott social media platfo...

# %%
# lemmatizer before tokenization
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk
football clubs were joined by European footballs governing body UEFA British Cycling the Rugby Football Union RFU the England and Wales Cricket Board ECB and Formula One world champion Lewis Hamilton among others plus media companies including Sky Sports and BT Sport Sky Sports stands with our football cricket and other sport partners to urge social media companies to do more to eradicate online hate and ensure social media can be a place for sports fans to discuss debate and consume the best sporting action without discrimination and abuse the broadcaster said Announcing it was joining thexa0boycottxa0this week BT Sport said the horrific cycle of online abuse had to end The International Tennis Federation ITF was one of the bodies to join on Friday The level of abuse individuals are forced to endure is completely unacceptable which is why we are calling on social media companies to act now to protect individuals who are merely doing their jobs ITF president David Haggerty said READ MORE English football to boycott Facebook and Twitter over online abuse In support of our partners BT Sport to Draw the Line against social media abuse Dragons Scarlets Cardiff Blues Ospreys  the Welsh Rugby Union will be joining clubs  sporting organisations across the country in a social media boycott this weekend pictwittercomxPej8qGwGE Call for change In response to the boycott Twitter said that since the English football season started in September it had removed 7000 of the 30 million Tweets in the UK about football Racist behaviour abuse and harassment have absolutely no place on our service and alongside our partners in football we condemn racism in all its forms a Twitter spokesperson said We are resolute in our commitment to ensure the football conversation on our service is safe for fans players and everyone involved in the game A Facebook company spokesperson said No one should have to experience abuse anywhere and its against our policies to harass or discriminate against people on Instagram or Facebook We agree with and have already made progress on many of the players’ suggestions including taking tougher action against people breaking our rules in DMs We also recently announced that starting next week well provide new tools based on consultation with footballers and antidiscrimination experts to help prevent people seeing abusive messages from strangers We continue to work with UK police on hate speech and respond to valid legal requests for information which can be essential for investigations We’ll continue listening to feedback and keep fighting hate and racism on our platform Britains seventimes Formula One world champion Hamilton has switched off his social media channels in a show of support While a boycott might not solve this issue overnight we have to call for change when needed even when it seems like an almost impossi ...
#
#                                                                     keywords_from_url
# 0  sport aussie women cricketers wage hike fails to close big gap 50710
# 1  sport tennis world concerned over whereabouts of china s peng shuai 51760
# 2  sport barty pulls out of wta finals to focus on australian open preparations 51014
# 3  sport beijing lights the flame kicking off 2022 winter olympic games 50893
# 4  sport sport bodies boycott social media platforms over online abuse 46360

# %%
#instantiate  lemmatizer after tokenization

from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
  lemma = [lemmatizer.lemmatize(i) for i in text]
  return lemma

# %%
df['title'] = df['title'].apply(lambda x : word_lemmatizer(x))
df['article'] = df['article'].apply(lambda x : word_lemmatizer(x))
df['keywords_from_url'] = df['keywords_from_url'].apply(lambda x : word_lemmatizer(x))

# %%
df.sample(5)
# Out:
#             tag              datetime  \
# 705    business  29/06/2022, 10:46:06
# 329        cars  29/06/2022, 10:12:30
# 630    football  29/06/2022, 10:38:59
# 1664  education  29/06/2022, 12:17:33
# 1343  education  29/06/2022, 11:47:56
#
#                                                   title  \
# 705   [netanyahu, played, trump, misinformation, til...
# 329   [uk, plans, ban, sale, diesel, petrol, cars, 2...
# 630   [messi, leave, barcelona, contract, talks, col...
# 1664  [taliban, threat, leads, teen, wrestler, new, ...
# 1343  [south, korea, quake, postpones, lifedefining,...
#
#                                                 article  \
# 705   [israeli, prime, minister, benjamin, netanyahu...
# 329   [united, kingdom, announced, would, ban, sale,...
# 630   [lionel, messi, end, 20year, career, barcelona...
# 1664  [afghan, teenager, zaki, mohsin, come, long, w...
# 1343  [south, korean, students, expressed, confusion...
#
#                                       keywords_from_url
# 705   [middle, east, netanyahu, played, trump, misin...
# 329   [business, uk, plans, ban, sale, diesel, petro...
# 630   [sport, messi, leave, barcelona, contract, tal...
# 1664  [americas, taliban, threat, leads, teenager, n...
# 1343  [asia, south, korea, quake, postpones, life, d...

# %%
#stemming not applied

'''# import stemmer 
from nltk.stem.porter import PorterStemmer
# instantiate stemmer
stemmer = PorterStemmer()

def word_stemmer(text):
  stemma = " ".join([stemmer.stem(i) for i in text ])
  return stemma
  
df['keywords_from_url'].apply(lambda x: word_stemmer(x))

  '''

# %%
df
# Out:
#           tag              datetime  \
# 0       sport  29/06/2022, 09:41:10
# 1       sport  29/06/2022, 09:41:13
# 2       sport  29/06/2022, 09:41:17
# 3       sport  29/06/2022, 09:41:20
# 4       sport  29/06/2022, 09:41:24
# ...       ...                   ...
# 2383  cricket  29/06/2022, 13:21:58
# 2384  cricket  29/06/2022, 13:22:01
# 2385  cricket  29/06/2022, 13:22:04
# 2386  cricket  29/06/2022, 13:22:07
# 2387  cricket  29/06/2022, 13:22:10
#
#                                                   title  \
# 0     [aussie, women, cricketers, wage, hike, fails,...
# 1     [tennis, world, concerned, whereabouts, chinas...
# 2     [barty, pulls, wta, finals, focus, australian,...
# 3     [beijing, lights, flame, kicking, 2022, winter...
# 4     [sport, bodies, boycott, social, media, platfo...
# ...                                                 ...
# 2383  [afghanistan, beat, ireland, qualify, cricket,...
# 2384  [australia, admit, ball, tampering, stunning, ...
# 2385  [australia, jeered, south, african, crowd, bal...
# 2386        [jones, extends, england, dream, job, 2021]
# 2387        [australia, thrash, england, ashes, opener]
#
#                                                 article  \
# 0     [australias, women, cricketers, get, pay, rise...
# 1     [amid, concerns, whereabouts, chinese, tennis,...
# 2     [world, number, one, ash, barty, defend, wta, ...
# 3     [china, lit, olympic, flame, beijing, ceremoni...
# 4     [british, footballinstigated, boycott, worlds,...
# ...                                                 ...
# 2383  [afghanistan, losing, opening, three, qualifyi...
# 2384  [cricket, australia, said, sunday, steve, smit...
# 2385  [muted, chorus, boos, greeted, australia, stan...
# 2386  [england, coach, eddie, jones, said, winning, ...
# 2387  [david, warner, cameron, bancroft, got, requir...
#
#                                       keywords_from_url
# 0     [sport, aussie, women, cricketers, wage, hike,...
# 1     [sport, tennis, world, concerned, whereabouts,...
# 2     [sport, barty, pulls, wta, finals, focus, aust...
# 3     [sport, beijing, lights, flame, kicking, 2022,...
# 4     [sport, sport, bodies, boycott, social, media,...
# ...                                                 ...
# 2383  [sport, afghanistan, beat, ireland, qualify, c...
# 2384  [sport, australia, admit, ball, tampering, stu...
# 2385  [sport, australia, jeered, south, african, cro...
# 2386  [sport, jones, extends, england, dream, job, 2...
# 2387  [sport, australia, thrash, england, ashes, ope...
#
# [2386 rows x 5 columns]

# %%
# install the spacy 
pip install -U spacy

#Install the spaCy Lemmatization
pip install -U spacy-lookups-data

# install the spacy english model
# !python -m spacy download en_core_web_sm

# %%
#sentence segmentation
# Splitting text into sentences using spaCy
def split_sentences(document):
 sentences = [sent.string.strip() for sent in doc.sents]
 return sentences

# %%
# Removing Stopwords
# Removes stopwords from a sentence using spaCy (token.is_stop)
def remove_stopwords(sentence):
 sentence = nlp(sentence)
 processed_sentence = ' '.join([token.text for token in sentence if token.is_stop != True ])
 return processed_sentence
# Removes stopwords from spaCy default stopword list
nlp.Defaults.stop_words -= {"my_stopword_1", "my_stopword_2"}
# Adds custom stopwords into spaCy default stopword list
nlp.Defaults.stop_words |= {"my_stopword_1", "my_stopword_2"}
# Prints spaCy default stopwords
print(nlp.Defaults.stop_words)

# %%
# Removes punctuation and special chars from a sentence using spaCy 
def remove_punctuation_special_chars(sentence):
 sentence = nlp(sentence)
 processed_sentence = ' '.join([token.text for token in sentence 
 if token.is_punct != True and 
     token.is_quote != True and 
     token.is_bracket != True and 
     token.is_currency != True and 
     token.is_digit != True])
 return processed_sentence
# spaCy - List of special charecters to be removed
_currency = r"\$ £ € ¥ ฿ US\$ C\$ A\$ ₽ ﷼ ₴"
_punct = (
    r"… …… , : ; \! \? ¿ ؟ ¡ \( \) \[ \] \{ \} < > _ # \* & 。 ？ ！ ， 、 ； ： ～ · । ، ۔ ؛ ٪" )
_quotes = r'\' " ” “ ` ‘ ´ ’ ‚ , „ » « 「 」 『 』 （ ） 〔 〕 【 】 《 》 〈 〉'

# %%
# Lemmatization process with spaCy
def lemmatize_text(sentence):
    sentence = nlp(sentence)
    processed_sentence = ' '.join([word.lemma_ for word in 
    sentence])
    
    return processed_sentence

# %%
# JSONtoTXT.py
# Reads news articles from a JSON file
# Splits the content into sentences
# Cleans and normalizes the content
# Write each processed sentence into a text file
import json
import spacy
from spacy.lang.en import English # updated
from spacy.lang.en.stop_words import STOP_WORDS
from collections import Counter
import re
# Loads the spaCy small English language model
nlp = spacy.load('en_core_web_sm')
# Removes stopwords from spaCy default stopword list
nlp.Defaults.stop_words -= {"my_stopword_1", "my_stopword_2"}
# Adds custom stopword into spaCy default stopword list
nlp.Defaults.stop_words |= {"my_stopword_1", "my_stopword_2"}
print(nlp.Defaults)
# Calculates the frequency of words in a document
def word_frequency(my_doc):
# all tokens that arent stop words or punctuations
 words = [token.text for token in my_doc if token.is_stop != True 
 and token.is_punct != True]
# noun tokens that arent stop words or punctuations
 nouns = [token.text for token in my_doc if token.is_stop != True 
 and token.is_punct != True and token.pos_ == "NOUN"]
# verb tokens that arent stop words or punctuations
 verbs = [token.text for token in my_doc if token.is_stop != True 
 and token.is_punct != True and token.pos_ == "VERB"]
# five most common words
 word_freq = Counter(words)
 common_words = word_freq.most_common(5)
 print("---------------------------------------")
 print("5 MOST COMMON TOKEN")
 print(common_words)
 print("---------------------------------------")
 print("---------------------------------------")
# five most common nouns
 noun_freq = Counter(nouns)
 common_nouns = noun_freq.most_common(5)
 print("5 MOST COMMON NOUN")
 print(common_nouns)
 print("---------------------------------------")
 print("---------------------------------------")
# five most common verbs
 verb_freq = Counter(verbs)
 common_verbs = verb_freq.most_common(5)
 print("5 MOST COMMON VERB")
 print(common_verbs)
 print("---------------------------------------")
 print("---------------------------------------")
# Removes stopwords from a sentence using spaCy (token.is_stop)
def remove_stopwords(sentence):
 sentence = nlp(sentence)
 processed_sentence = ' '.join([token.text for token in sentence if 
 token.is_stop != True ])
 return processed_sentence
# Removes punctuation and special chars from a sentence using spaCy
def remove_punctuation_special_chars(sentence):
 sentence = nlp(sentence)
 processed_sentence = ' '.join([token.text for token in sentence 
  if token.is_punct != True and 
     token.is_quote != True and 
     token.is_bracket != True and 
     token.is_currency != True and 
     token.is_digit != True])
 return processed_sentence
# Lemmatization process with spaCy
def lemmatize_text(sentence):
    sentence = nlp(sentence)
    processed_sentence = ' '.join([word.lemma_ for word in 
    sentence])
    return processed_sentence
def remove_special_chars(text):
 bad_chars = ["%", "#", '"', "*"] 
 for i in bad_chars: 
  text = text.replace(i, '')
 return text
# Splitting text into sentences using spaCy
def split_sentences(document):
 sentences = [sent.string.strip() for sent in doc.sents]
 return sentences
sentence_index = 0
with open('/Users/erdemisbilen/TFvenv/articles_less.json') as json_file:
 data = json.load(json_file)
  
 with open("article_all.txt", "w") as text_file:
  for p in data:
   article_body = p['article_body']
   article_body = remove_special_chars(article_body)
doc = nlp(article_body)
sentences = split_sentences(doc)
   word_frequency(doc)
for sentence in sentences:
    sentence_index +=1
    print("Sentence #" + str(sentence_index) + "-----------------")
    print("Original Sentence               : " + sentence)
    sentence = remove_stopwords(sentence)
    sentence = remove_punctuation_special_chars(sentence)
    print("Stopwors and Punctuation Removal: " + sentence)
    sentence = lemmatize_text(sentence)
    print("Lemmitization Applied           : " + sentence)
    text_file.write(sentence + '\n')
  
 text_file.close()

# %% [markdown]
# ##**content based recommedation system**

# %%
df.head()
# Out:
#      tag                                              title  \
# 0  sport  aussie women cricketers wage hike fail close b...
# 1  sport  tennis world concern whereabouts chinas peng s...
# 2  sport  barty pull wta finals focus australian open pr...
# 3  sport  beijing light flame kick 2022 winter olympic game
# 4  sport  sport body boycott social media platforms onli...
#
#                                              article       time day month  \
# 0  Australias women cricketers will get a pay ris...   09:41:10  29    06
# 1  Amid concerns over the whereabouts of Chinese ...   09:41:13  29    06
# 2  World number one Ash Barty will not defend her...   09:41:17  29    06
# 3  China has lit its Olympic flame in Beijing aft...   09:41:20  29    06
# 4  A British footballinstigated boycott of the wo...   09:41:24  29    06
#
#    year                                  keywords_from_url
# 0  2022  sport aussie women cricketers wage hike fails ...
# 1  2022  sport tennis world concerned over whereabouts ...
# 2  2022  sport barty pulls out of wta finals to focus o...
# 3  2022  sport beijing lights the flame kicking off 202...
# 4  2022  sport sport bodies boycott social media platfo...

# %%
df.head(5)
# Out:
#      tag                                              title  \
# 0  sport  aussie women cricketers wage hike fail close b...
# 1  sport  tennis world concern whereabouts chinas peng s...
# 2  sport  barty pull wta finals focus australian open pr...
# 3  sport  beijing light flame kick 2022 winter olympic game
# 4  sport  sport body boycott social media platforms onli...
#
#                                              article  \
# 0  Australias women cricketers will get a pay ris...
# 1  Amid concerns over the whereabouts of Chinese ...
# 2  World number one Ash Barty will not defend her...
# 3  China has lit its Olympic flame in Beijing aft...
# 4  A British footballinstigated boycott of the wo...
#
#                                    keywords_from_url
# 0  sport aussie women cricketers wage hike fails ...
# 1  sport tennis world concerned over whereabouts ...
# 2  sport barty pulls out of wta finals to focus o...
# 3  sport beijing lights the flame kicking off 202...
# 4  sport sport bodies boycott social media platfo...

# %%
title_vectorizer = CountVectorizer()
title_features   = title_vectorizer.fit_transform(df['title'])

# %%
title_features.shape
# Out:
# (2386, 4290)

# %%
def bag_of_words_based_model(row_index, num_similar_items):
    couple_dist = pairwise_distances(title_features,title_features[row_index])
    indices = np.argsort(couple_dist.ravel())[0:num_similar_items]
    df_ = pd.DataFrame({'title':df['title'][indices].values,
                       'Euclidean similarity with the queried article': couple_dist[indices].ravel()})
    print("="*30,"Queried article details","="*30)
    print('titlee : ',df['title'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    #return df.iloc[1:,1]
    return df_.iloc[1:,]

bag_of_words_based_model(2, 10) # Change the row index for any other queried article
# Out:
# ============================== Queried article details ==============================
# titlee :  barty pull wta finals focus australian open preparations
#
#  ========================= Recommended articles :  =======================
#                                                       title  \
# 1  barty pull wta finals focus australian open preparations
# 2  milos raonic pull australian open heel injury
# 3  2021 australian open likely delay
# 4  turkey open school colombia
# 5  ashleigh barty storm miami open final
# 6  anthony scaramucci
# 7  serena pull french open achilles injury
# 8  federer skip french open focus wimbledon
# 9  wozniacki tennis career defeat australian open
#
#    Euclidean similarity with the queried article
# 1  0.000000
# 2  3.000000
# 3  3.000000
# 4  3.162278
# 5  3.162278
# 6  3.162278
# 7  3.162278
# 8  3.162278
# 9  3.162278

# %%
tfidf_title_vectorizer = TfidfVectorizer(min_df = 0)
tfidf_title_features = tfidf_title_vectorizer.fit_transform(df['title'])

# %%
def tfidf_based_model(row_index, num_similar_items):
    couple_dist = pairwise_distances(tfidf_title_features,tfidf_title_features[row_index])
    indices = np.argsort(couple_dist.ravel())[0:num_similar_items]
    df_ = pd.DataFrame({'title':df['title'][indices].values,
                        'Euclidean similarity with the queried article': couple_dist[indices].ravel()})
    print("="*30,"Queried article details","="*30)
    print('title : ',df['title'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    
    #return df.iloc[1:,1]
    return df_.iloc[1:,]
tfidf_based_model(2, 10)
# Out:
# ============================== Queried article details ==============================
# title :  barty pull wta finals focus australian open preparations
#
#  ========================= Recommended articles :  =======================
#                                                                   title  \
# 1  barty pull wta finals focus australian open preparations
