# %% [markdown]
# **EDA**

# %%
# importing the necessray liabaries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',None)

# %%
# reading the file
path = "/content/drive/MyDrive/adult.csv"
df = pd.read_csv(path)

# %%
# checking the shape
print(f"we have {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# we have 32561 rows and 15 columns

# %%
# output variable
output_var = df.columns[-1]
print(f"{output_var} is the Output varible in our data")
# Out:
# income is the Output varible in our data

# %% [markdown]
# **duplicate data**

# %%
# checking duplicated data 
duplicate_data = df.duplicated()
print(f"we have {duplicate_data.sum()} duplicate data")
# Out:
# we have 24 duplicate data

# %%
# we have duplicate data,removing them from our data
df.drop_duplicates(inplace = True)

# %%
# check the shape again
print(f"we have {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# we have 32537 rows and 15 columns

# %%
# checking duplicated data again
duplicate_data = df.duplicated()
print(f"we have {duplicate_data.sum()} duplicate data")
# Out:
# we have 0 duplicate data

# %% [markdown]
# **missing values**

# %%
#checking the missing value 
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education.num     0
# marital.status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital.gain      0
# capital.loss      0
# hours.per.week    0
# native.country    0
# income            0
# dtype: int64

# %% [markdown]
# we don't have any missing values in our data.

# %% [markdown]
# **data type**

# %%
# check the data types of all the variables
print(f"Here are the data types of all the variables in out data \n{df.dtypes}")
# Out:
# Here are the data types of all the variables in out data
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education.num      int64
# marital.status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital.gain       int64
# capital.loss       int64
# hours.per.week     int64
# native.country    object
# income            object
# dtype: object

# %%
#made a different- different list fot object and numerical data types

obj_data_types = df.select_dtypes(include='object')
obj_data_types = obj_data_types.columns.tolist()
print(f"we have {len(obj_data_types)} object data types")
print(obj_data_types)

num_data_types = df.select_dtypes(include='int64')
num_data_types = num_data_types.columns.tolist()
print(f"\nwe have {len(num_data_types)} numerical data types")
print(num_data_types)
# Out:
# we have 9 object data types
# ['workclass', 'education', 'marital.status', 'occupation', 'relationship', 'race', 'sex', 'native.country', 'income']
#
# we have 6 numerical data types
# ['age', 'fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week']

# %%
# checking the unique values
for column in df.columns:
  print(f"\nIn {column} column, we have {df[column].nunique()} unique values")
# Out:
# In age column, we have 73 unique values
#
# In workclass column, we have 9 unique values
#
# In fnlwgt column, we have 21648 unique values
#
# In education column, we have 16 unique values
#
# In education.num column, we have 16 unique values
#
# In marital.status column, we have 7 unique values
#
# In occupation column, we have 15 unique values
#
# In relationship column, we have 6 unique values
#
# In race column, we have 5 unique values
#
# In sex column, we have 2 unique values
#
# In capital.gain column, we have 119 unique values
#
# In capital.loss column, we have 92 unique values
#
# In hours.per.week column, we have 94 unique values
#
# In native.country column, we have 42 unique values
#
# In income column, we have 2 unique values

# %%
# let check the value counts of all the columns
for column in df.columns:
    print(f"\n{df[column].value_counts()} ")
# Out:
# Streaming output truncated to the last 5000 lines.
# 336226      1
# 276456      1
# 293485      1
# 160942      1
# 172220      1
# 82628       1
# 154580      1
# 179953      1
# 257940      1
# 248833      1
# 216390      1
# 104896      1
# 214594      1
# 296045      1
# 30069       1
# 326342      1
# 213574      1
# 116084      1
# 241469      1
# 240817      1
# 186925      1
# 163729      1
# 157308      1
# 164229      1
# 151551      1
# 99076       1
# 79870       1
# 160951      1
# 153356      1
# 83622       1
# 82465       1
# 212091      1
# 269583      1
# 141113      1
# 326199      1
# 198188      1
# 203525      1
# 171831      1
# 107575      1
# 483596      1
# 302142      1
# 279538      1
# 116468      1
# 247232      1
# 407138      1
# 48718       1
# 55674       1
# 544686      1
# 116044      1
# 104993      1
# 225859      1
# 174856      1
# 286487      1
# 306678      1
# 156763      1
# 165365      1
# 57052       1
# 205256      1
# 345405      1
# ...

# %% [markdown]
# after checking unique values and value counts i made following varibles:

# %%
binary_categ_var = ['income','sex']
nominal_categ_var = ['workclass','marital.status','occupation','relationship','race','native.country']
ordinal_categ_var = ['education','education.num']
continuous_var = ['age','fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week']
# Out:
# Male      21775
# Female    10762
# Name: sex, dtype: int64
#
# 0        29825
# 15024      347
# 7688       284
# 7298       246
# 99999      159
# 5178        97
# 3103        97
# 4386        70
# 5013        69
# 8614        55
# 3325        53
# 2174        48
# 10520       43
# 4064        42
# 4650        41
# 14084       41
# 20051       37
# 3137        37
# 594         34
# 27828       34
# 3908        32
# 2829        31
# 13550       27
# 6849        27
# 14344       26
# 1055        25
# 3411        24
# 2885        24
# 3464        23
# 2176        23
# 4787        23
# 9386        22
# 4101        20
# 2597        20
# 2407        19
# 4865        17
# 2202        16
# 1506        15
# 3942        14
# 3674        14
# 2580        12
# 10605       12
# 3781        12
# 4508        12
# 4416        12
# 5455        11
# 6497        11
# 25236       11
# 2354        11
# 2463        11
# 2907        11
# 2635        11
# 6418         9
# 7430         9
# 2105         9
# ...

# %%
df.head(3)
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
#
#         occupation   relationship   race     sex  capital.gain  capital.loss  \
# 0                ?  Not-in-family  White  Female             0          4356
# 1  Exec-managerial  Not-in-family  White  Female             0          4356
# 2                ?      Unmarried  Black  Female             0          4356
#
#    hours.per.week native.country income
# 0              40  United-States  <=50K
# 1              18  United-States  <=50K
# 2              40  United-States  <=50K

# %% [markdown]
# we can see in some columns we have question mark,let'check in which columns we have qquestion marks.

# %%
question_mark = "?"
question_mark = df.isin([question_mark]).any()
print(question_mark)
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education.num     False
# marital.status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital.gain      False
# capital.loss      False
# hours.per.week    False
# native.country     True
# income            False
# dtype: bool

# %% [markdown]
# so we have question mark in three nominal categorical variable columns which is workclass,occupation,and native.country

# %%
# so plotting heat map to get the visuals insights
question_mark = "?"
question_mark = df.isin([question_mark])
plt.figure(figsize = (20,8))
sns.heatmap(question_mark);

# %%
# let's see the percentage of question marks we have in particular column
question_mark = "?"
question_mark = df.isin([question_mark]).sum()
question_mark/df.shape[0]*100
# Out:
# age               0.000000
# workclass         5.642807
# fnlwgt            0.000000
# education         0.000000
# education.num     0.000000
# marital.status    0.000000
# occupation        5.664321
# relationship      0.000000
# race              0.000000
# sex               0.000000
# capital.gain      0.000000
# capital.loss      0.000000
# hours.per.week    0.000000
# native.country    1.788733
# income            0.000000
# dtype: float64

# %% [markdown]
# In workclass column 5.64% percent,occupation column 5.66% and native.country 1.79% columns have question mark sign

# %% [markdown]
# We will think about filling the question marks after doing some univariate analysis

# %% [markdown]
# **univariate analysis**

# %% [markdown]
# Binary Categorical variable = ['income',  'sex']

# %%
# count plot of binary categorical variable

binary_categ_var = ['income','sex']

plt.figure(figsize = (10,5))
for i,var in enumerate(binary_categ_var):
  plt.subplot(1,2,i+1)
  sns.countplot(x = var,data = df)

# checking the proportion of each categoty in percentage terms
print((df['income'].value_counts())/len(df['income'])*100)
print()
print((df['sex'].value_counts())/len(df['sex'])*100)
# Out:
# <=50K    75.907428
# >50K     24.092572
# Name: income, dtype: float64
#
# Male      66.92381
# Female    33.07619
# Name: sex, dtype: float64

# %% [markdown]
# Income =     75.91 % have income <=50K,  24.09 % have income >50K
#
# Sex  =       66.92 % are male, 33.07 % are female
#
# Data is imbalnced betweena sex and income.
#
# Big chunk of records from data earn less than <=50K
#
# And in sex too, male are way more than female .

# %% [markdown]
# > nominal_categ_var = ['workclass','marital.status','occupation','relationship','race','native.country']

# %%
# Pie plot of nominal categorical variable

nominal_categ_var = ['workclass','marital.status','occupation','relationship','race','native.country']

for nominal in nominal_categ_var:
  plt.figure(figsize = (5,5))
  fig = px.pie(df,values =df[nominal].value_counts().values,names =df[nominal].value_counts().index,title = nominal)
  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# workclass = Majority of the entries belongs to private class
#
# marital.status = almost half of the entries are married-civ-spouse followed by never married
#
# Occupation = Distibution is widely spread between many occupation
#
# relationship = distribution of husband is in majority followed by not married
#
# race = almost 85 percent are white people
#
# native.country = almost 90 percent have united states their native country

# %% [markdown]
# ordinal_categ_var = ['education','education.num']

# %%
# plotting the count plot for ordinal categorical variable

ordinal_categ_var = ['education','education.num']
plt.figure(figsize = (10,5))
for i,var in enumerate(ordinal_categ_var):
  plt.subplot(1,2,i+1)
  sns.countplot(y = var,data = df)

# checking the proportion of each categoty in percentage terms
print((df['education'].value_counts())/len(df['education'])*100)
print()
print((df['education.num'].value_counts())/len(df['education.num'])*100)
# Out:
# HS-grad         32.252513
# Some-college    22.380674
# Bachelors       16.452039
# Masters          5.292436
# Assoc-voc        4.247472
# 11th             3.611273
# Assoc-acdm       3.279344
# 10th             2.867505
# 7th-8th          1.982359
# Prof-school      1.770292
# 9th              1.579740
# 12th             1.330793
# Doctorate        1.269324
# 5th-6th          1.020377
# 1st-4th          0.510188
# Preschool        0.153671
# Name: education, dtype: float64
#
# 9     32.252513
# 10    22.380674
# 13    16.452039
# 14     5.292436
# 11     4.247472
# 7      3.611273
# 12     3.279344
# 6      2.867505
# 4      1.982359
# 15     1.770292
# 5      1.579740
# 8      1.330793
# 16     1.269324
# 3      1.020377
# 2      0.510188
# 1      0.153671
# Name: education.num, dtype: float64

# %% [markdown]
# education and education.num both consists same data so later we will drop one column
#
# 32 % of the people are HS-Grad followed by 22 % belong to some college and then 16 % are bachelors

# %% [markdown]
# continuous_var = ['age','fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week']

# %%
# disribution of continuous variables

continuous_variable = ['age', 'fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week']

plt.figure(figsize = (15,15))
for i,var in enumerate(continuous_variable):
  plt.subplot(3,2,i+1)
  sns.histplot(x= var,bins = 50,data = df,kde = True )

# %% [markdown]
# Age = distribution is right skewed, we have highe rnumber of entries who belongs to 20-45 and as the age is increasing we have less number of the entries
#
# fnlwgt = it is also right skewed
#
# capital.gain = most number of the entries have capital.gain around 0 -5000 and very less number of entries have capital.gain more than 5000
#
# capital.loss = most number of entries have capital.loss around 0-200(approx), we few people who have capital.gain around 2000
#
# hours.per.week = large chunk of entries work around 40 hours, and then peole who work more than 40 hours are slighly more than people who work less than 40 hours.

# %%
# # disribution of continuous variables by box plot 

continuous_variable = ['age', 'fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week']
plt.figure(figsize = (15,15))
for i,var in enumerate(continuous_variable):
  plt.subplot(3,2,i+1)
  sns.boxplot(x= var,data = df)

# %% [markdown]
# we have lot of outliers in continuous variable

# %% [markdown]
# **Bivariate Analysis/Multivaraite analysis**

# %%
# check the relationship between continuous variable and output variable

continuous_variable = ['age', 'fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week']

plt.figure(figsize = (15,15))
for i,var in enumerate(continuous_variable):
  plt.subplot(3,2,i+1)
  sns.boxplot(y= var,x = output_var,data = df)

# %% [markdown]
# There is some relation between age and hours.per.week with income
#
# people who have income more than 50 k have higher median and iqr in age and hours.per.week relatinship with income

# %%
# check the relationship between ordinal variable and output variable
ordinal_categ_var = ['education','education.num']
plt.figure(figsize = (20,30))
for i,var in enumerate(ordinal_categ_var): 
  plt.subplot(6,2,i+1)
  sns.histplot(data=df, y=df[var], hue="income",multiple ="dodge",binwidth=2,bins=10,stat = 'percent')

# %% [markdown]
# people who are doctorate,profschool and masters have higher probability to earn more than 50 k

# %%
#realtionship between nominal categoreies and output variable
nominal_categ_var = ['workclass','marital.status','occupation','relationship','race','native.country']

plt.figure(figsize = (20,30))
for i,var in enumerate(nominal_categ_var): 
  plt.subplot(6,2,i+1)
  sns.histplot(data=df, y=df[var], hue="income",multiple ="dodge",binwidth=2,bins=10,stat = 'percent')

# %% [markdown]
# In workclass self emp inc have higher probabilty to earn more than 50k followed by federal goovernment
#
# In marital.status married-civ-spouse have higher probabilty to earn more than 50 k
#
# In occupation ,Exec-managerial,prof-speciality have higher probabilty to earn more than 50 k
#
# In relationship wife have more probabilty to earn more than 50k than husband
#
# In race and native.country there is no significant relationship.

# %%
#realtionship between binary category and output variable
binary_categ_var = ['sex']
sns.histplot(data=df, x='sex', hue="income",multiple ="dodge",binwidth=2,bins=10,stat = 'percent');

# %% [markdown]
# there are less number of female are earning more than 50k as compared to male

# %%
# check the relationship between continuous variable and output variable with hue as sex

continuous_variable = ['age', 'fnlwgt', 'capital.gain', 'capital.loss', 'hours.per.week']

plt.figure(figsize = (15,15))
for i,var in enumerate(continuous_variable):
  plt.subplot(3,2,i+1)
  sns.boxplot(y= var,x = output_var,data = df,hue= 'sex')

# %% [markdown]
# In the age and income plot,male are slighlty more than female in case of income more than 50k
#
# male works more than female in both the cases whether its more than or less than 50k

# %%
# check the relaionship between capital.gain and income hue as sex
sns.catplot(x="income", y="capital.gain", hue="sex", kind="bar", data=df);

# %% [markdown]
# people who earn more than 50k have significant capital.gain and female are on higher side as compared to men in case of more than 50k

# %%
# check the relaionship between capital.loss and income hue as sex
sns.catplot(x="income", y="capital.loss", hue="sex", kind="bar", data=df);

# %% [markdown]
# people who earn less than 50k have significant rise in capital.loss as compared to capital.gain, here people who earn more than 50k also have significant rise and female have less capital.loss as compared to male in case of more than 50k

# %%
sns.pairplot(df,hue = 'sex',height = 2.5)

# %%
sns.pairplot(df,hue = 'income',height = 2.5)
